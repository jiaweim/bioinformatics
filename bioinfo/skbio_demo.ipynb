# %%
import skbio

print(skbio.title)
print(skbio.art)
# Out:
# *                                                    *
#                _ _    _ _          _     _
#               (_) |  (_) |        | |   (_)
#       ___  ___ _| | ___| |_ ______| |__  _  ___
#      / __|/ __| | |/ / | __|______| '_ \| |/ _ \
#      \__ \ (__| |   <| | |_       | |_) | | (_) |
#      |___/\___|_|_|\_\_|\__|      |_.__/|_|\___/
#
# *                                                    *
#
#
#
#            Opisthokonta
#                    \  Amoebozoa
#                     \ /
#                      *    Euryarchaeota
#                       \     |_ Crenarchaeota
#                        \   *
#                         \ /
#                          *
#                         /
#                        /
#                       /
#                      *
#                     / \
#                    /   \
#         Proteobacteria  \
#                        Cyanobacteria
